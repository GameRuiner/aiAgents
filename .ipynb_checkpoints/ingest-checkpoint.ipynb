# %%
from agentlib.knowledge_loader import KnowledgeLoader

# %%
loader = KnowledgeLoader("google", "adk-python")
docs = loader.load_repository()

# %%
f"ADK documents: {len(docs)}"
# Out:
# 'ADK documents: 99'

# %%
docs[0]
# Out:
# {'name': 'Bug report',
#  'about': 'Create a report to help us improve',
#  'title': '',
#  'labels': '',
#  'assignees': '',
#  'content': "## 🔴 Required Information\n*Please ensure all items in this section are completed to allow for efficient\ntriaging. Requests without complete information may be rejected / deprioritized.\nIf an item is not applicable to you - please mark it as N/A*\n\n**Describe the Bug:**\nA clear and concise description of what the bug is.\n\n**Steps to Reproduce:**\nPlease provide a numbered list of steps to reproduce the behavior:\n1. Install '...'\n2. Run '....'\n3. Open '....'\n4. Provide error or stacktrace\n\n**Expected Behavior:**\nA clear and concise description of what you expected to happen.\n\n**Observed Behavior:**\nWhat actually happened? Include error messages or crash stack traces here.\n\n**Environment Details:**\n\n - ADK Library Version (pip show google-adk):\n - Desktop OS:** [e.g., macOS, Linux, Windows]\n - Python Version (python -V):\n\n**Model Information:**\n\n - Are you using LiteLLM: Yes/No\n - Which model is being used: (e.g., gemini-2.5-pro)\n\n---\n\n## 🟡 Optional Information\n*Providing this information greatly speeds up the resolution process.*\n\n**Regression:**\nDid this work in a previous version of ADK? If so, which one?\n\n**Logs:**\nPlease attach relevant logs. Wrap them in code blocks (```) or attach a\ntext file.\n```text\n// Paste logs here\n```\n\n**Screenshots / Video:**\nIf applicable, add screenshots or screen recordings to help explain\nyour problem.\n\n**Additional Context:**\nAdd any other context about the problem here.\n\n**Minimal Reproduction Code:**\nPlease provide a code snippet or a link to a Gist/repo that isolates the issue.\n```python\n// Code snippet here\n```\n\n**How often has this issue occurred?:**\n\n - Always (100%)\n - Often (50%+)\n - Intermittently (<50%)\n - Once / Rare",
#  'filename': 'adk-python-main/.github/ISSUE_TEMPLATE/bug_report.md'}

# %%
adk_chunks = []

for doc in docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    chunks = loader.chunk_sliding_window(doc_content, 2000, 1000)
    for chunk in chunks:
        chunk.update(doc_copy)
    adk_chunks.extend(chunks)

# %%
len(adk_chunks), adk_chunks[0]
# Out:
# (475,
#  {'start': 0,
#   'chunk': "## 🔴 Required Information\n*Please ensure all items in this section are completed to allow for efficient\ntriaging. Requests without complete information may be rejected / deprioritized.\nIf an item is not applicable to you - please mark it as N/A*\n\n**Describe the Bug:**\nA clear and concise description of what the bug is.\n\n**Steps to Reproduce:**\nPlease provide a numbered list of steps to reproduce the behavior:\n1. Install '...'\n2. Run '....'\n3. Open '....'\n4. Provide error or stacktrace\n\n**Expected Behavior:**\nA clear and concise description of what you expected to happen.\n\n**Observed Behavior:**\nWhat actually happened? Include error messages or crash stack traces here.\n\n**Environment Details:**\n\n - ADK Library Version (pip show google-adk):\n - Desktop OS:** [e.g., macOS, Linux, Windows]\n - Python Version (python -V):\n\n**Model Information:**\n\n - Are you using LiteLLM: Yes/No\n - Which model is being used: (e.g., gemini-2.5-pro)\n\n---\n\n## 🟡 Optional Information\n*Providing this information greatly speeds up the resolution process.*\n\n**Regression:**\nDid this work in a previous version of ADK? If so, which one?\n\n**Logs:**\nPlease attach relevant logs. Wrap them in code blocks (```) or attach a\ntext file.\n```text\n// Paste logs here\n```\n\n**Screenshots / Video:**\nIf applicable, add screenshots or screen recordings to help explain\nyour problem.\n\n**Additional Context:**\nAdd any other context about the problem here.\n\n**Minimal Reproduction Code:**\nPlease provide a code snippet or a link to a Gist/repo that isolates the issue.\n```python\n// Code snippet here\n```\n\n**How often has this issue occurred?:**\n\n - Always (100%)\n - Often (50%+)\n - Intermittently (<50%)\n - Once / Rare",
#   'name': 'Bug report',
#   'about': 'Create a report to help us improve',
#   'title': '',
#   'labels': '',
#   'assignees': '',
#   'filename': 'adk-python-main/.github/ISSUE_TEMPLATE/bug_report.md'})

# %%
adk_chunks = []

for doc in docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    paragraphs = loader.chunk_by_paragraphs(doc_content)
    for chunk in paragraphs:
        chunk_doc = doc_copy.copy()
        chunk_doc['section'] = chunk
        chunk_doc.update(doc_copy)
        adk_chunks.append(chunk_doc)

# %%
len(adk_chunks), adk_chunks[0]
# Out:
# (2689,
#  {'name': 'Bug report',
#   'about': 'Create a report to help us improve',
#   'title': '',
#   'labels': '',
#   'assignees': '',
#   'filename': 'adk-python-main/.github/ISSUE_TEMPLATE/bug_report.md',
#   'section': '## 🔴 Required Information\n*Please ensure all items in this section are completed to allow for efficient\ntriaging. Requests without complete information may be rejected / deprioritized.\nIf an item is not applicable to you - please mark it as N/A*'})

# %%
adk_chunks = []

for doc in docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    sections = loader.chunk_by_headers(doc_content, level=2)
    for section in sections:
        section_doc = doc_copy.copy()
        section_doc['section'] = section
        adk_chunks.append(section_doc)

# %%
len(adk_chunks), adk_chunks[0]
# Out:
# (390,
#  {'name': 'Bug report',
#   'about': 'Create a report to help us improve',
#   'title': '',
#   'labels': '',
#   'assignees': '',
#   'filename': 'adk-python-main/.github/ISSUE_TEMPLATE/bug_report.md',
#   'section': "## 🔴 Required Information\n\n*Please ensure all items in this section are completed to allow for efficient\ntriaging. Requests without complete information may be rejected / deprioritized.\nIf an item is not applicable to you - please mark it as N/A*\n\n**Describe the Bug:**\nA clear and concise description of what the bug is.\n\n**Steps to Reproduce:**\nPlease provide a numbered list of steps to reproduce the behavior:\n1. Install '...'\n2. Run '....'\n3. Open '....'\n4. Provide error or stacktrace\n\n**Expected Behavior:**\nA clear and concise description of what you expected to happen.\n\n**Observed Behavior:**\nWhat actually happened? Include error messages or crash stack traces here.\n\n**Environment Details:**\n\n - ADK Library Version (pip show google-adk):\n - Desktop OS:** [e.g., macOS, Linux, Windows]\n - Python Version (python -V):\n\n**Model Information:**\n\n - Are you using LiteLLM: Yes/No\n - Which model is being used: (e.g., gemini-2.5-pro)\n\n---"})
